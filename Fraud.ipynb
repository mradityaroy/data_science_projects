# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('fraud_CreditData1.csv')
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0       6/21/2020 12:14  2.291160e+15
# 1           1       6/21/2020 12:14  3.573030e+15
# 2           2       6/21/2020 12:14  3.598220e+15
# 3           3       6/21/2020 12:15  3.591920e+15
# 4           4       6/21/2020 12:15  3.526830e+15
#
#                          merchant        category    amt   first      last  \
# 0                 Kirlin and Sons   personal_care   2.86    Jeff   Elliott
# 1                  Sporer-Keebler   personal_care  29.84  Joanne  Williams
# 2  Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley     Lopez
# 3                     Haley Group        misc_pos  60.05   Brian  Williams
# 4                 Johnston-Casper          travel   3.19  Nathan    Massey
#
#   gender                       street  ...      lat      long  city_pop  \
# 0      M            351 Darlene Green  ...  33.9659  -80.9355    333497
# 1      F             3638 Marsh Union  ...  40.3207 -110.4360       302
# 2      F         9333 Valentine Point  ...  40.6729  -73.5365     34496
# 3      M  32941 Krystal Mill Apt. 552  ...  28.5697  -80.8191     54767
# 4      M     5783 Evan Roads Apt. 465  ...  44.2529  -85.0170      1126
#
#                       job         dob                         trans_num  \
# 0     Mechanical engineer   3/19/1968  2da90c7d74bd46a0caf3777415b3ebd3
# 1  Sales professional, IT   1/17/1990  324cc204407e99f51b0d6ca0055005e7
# 2       Librarian, public  10/21/1970  c81755dbbbea9d5c77f094348a7579be
# 3            Set designer   7/25/1987  2159175b9efe66dc301f149d3d5abf8c
# 4      Furniture designer    7/6/1955  57ff021bd3f328f8738bb535c302a31b
#
#     unix_time  merch_lat  merch_long  is_fraud
# 0  1371816865  33.986391  -81.200714         0
# 1  1371816873  39.450498 -109.960431         0
# 2  1371816893  40.495810  -74.196111         0
# 3  1371816915  28.812398  -80.883061         0
# 4  1371816917  44.959148  -85.884734         0
#
# [5 rows x 23 columns]

# %%
fraud_trans = data.loc[data['is_fraud'] == 1]
normal_trans = data.loc[data['is_fraud'] == 0]

# %%
len(fraud_trans)
# Out:
# 2145

# %%
len(normal_trans)
# Out:
# 553574

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
x = data.iloc[:,:-1]
y = data['is_fraud']

# %%
x
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0       6/21/2020 12:14  2.291160e+15
# 1                1       6/21/2020 12:14  3.573030e+15
# 2                2       6/21/2020 12:14  3.598220e+15
# 3                3       6/21/2020 12:15  3.591920e+15
# 4                4       6/21/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 555714      555714      12/31/2020 23:59  3.056060e+13
# 555715      555715      12/31/2020 23:59  3.556610e+15
# 555716      555716      12/31/2020 23:59  6.011720e+15
# 555717      555717      12/31/2020 23:59  4.079770e+12
# 555718      555718      12/31/2020 23:59  4.170690e+15
#
#                               merchant        category     amt    first  \
# 0                      Kirlin and Sons   personal_care    2.86     Jeff
# 1                       Sporer-Keebler   personal_care   29.84   Joanne
# 2       Swaniawski, Nitzsche and Welch  health_fitness   41.28   Ashley
# 3                          Haley Group        misc_pos   60.05    Brian
# 4                      Johnston-Casper          travel    3.19   Nathan
# ...                                ...             ...     ...      ...
# 555714                 Reilly and Sons  health_fitness   43.77  Michael
# 555715                  Hoppe-Parisian       kids_pets  111.84     Jose
# 555716                       Rau-Robel       kids_pets   86.88      Ann
# 555717                 Breitenberg LLC          travel    7.99     Eric
# 555718                     Dare-Marvin   entertainment   38.13   Samuel
#
#             last gender                       street  ...    zip      lat  \
# 0        Elliott      M            351 Darlene Green  ...  29209  33.9659
# 1       Williams      F             3638 Marsh Union  ...  84002  40.3207
# 2          Lopez      F         9333 Valentine Point  ...  11710  40.6729
# 3       Williams      M  32941 Krystal Mill Apt. 552  ...  32780  28.5697
# 4         Massey      M     5783 Evan Roads Apt. 465  ...  49632  44.2529
# ...          ...    ...                          ...  ...    ...      ...
# 555714     Olson      M          558 Michael Estates  ...  63453  40.4931
# 555715   Vasquez      M          572 Davis Mountains  ...  77566  29.0393
# 555716    Lawson      F   144 Evans Islands Apt. 683  ...  99323  46.1966
# 555717   Preston      M   7020 Doyle Stream Apt. 951  ...  83643  44.6255
# 555718      Frey      M     830 Myers Plaza Apt. 384  ...  73034  35.6665
#
#             long  city_pop                     job         dob  \
# 0       -80.9355    333497     Mechanical engineer   3/19/1968
# 1      -110.4360       302  Sales professional, IT   1/17/1990
# 2       -73.5365     34496       Librarian, public  10/21/1970
# 3       -80.8191     54767            Set designer   7/25/1987
# 4       -85.0170      1126      Furniture designer    7/6/1955
# ...          ...       ...                     ...         ...
# 555714  -91.8912       519            Town planner   2/13/1966
# 555715  -95.4401     28739          Futures trader  12/27/1999
# 555716 -118.9017      3684                Musician  11/29/1981
# 555717 -116.4493       129            Cartographer  12/15/1965
# 555718  -97.4798    116001             Media buyer   5/10/1993
#
#                                trans_num   unix_time  merch_lat  merch_long
# 0       2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1       324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
# 2       c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810  -74.196111
# 3       2159175b9efe66dc301f149d3d5abf8c  1371816915  28.812398  -80.883061
# 4       57ff021bd3f328f8738bb535c302a31b  1371816917  44.959148  -85.884734
# ...                                  ...         ...        ...         ...
# 555714  9b1f753c79894c9f4b71f04581835ada  1388534347  39.946837  -91.333331
# 555715  2090647dac2c89a1d86c514c427f5b91  1388534349  29.661049  -96.186633
# 555716  6c5b7c8add471975aa0fec023b2e8408  1388534355  46.658340 -119.715054
# 555717  14392d723bb7737606b2700ac791b7aa  1388534364  44.470525 -117.080888
# 555718  1765bb45b3aa3224b4cdcb6e7a96cee3  1388534374  36.210097  -97.036372
#
# [555719 rows x 22 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 555714    0
# 555715    0
# 555716    0
# 555717    0
# 555718    0
# Name: is_fraud, Length: 555719, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35)

# %%
x_train
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 37619        37619        7/4/2020 15:55  4.379260e+18
# 5400          5400       6/22/2020 20:31  3.589290e+15
# 297501      297501      10/11/2020 17:52  1.800310e+14
# 367709      367709      11/10/2020 18:00  3.858850e+13
# 312634      312634      10/18/2020 11:27  2.131260e+14
# ...            ...                   ...           ...
# 94190        94190        7/24/2020 4:15  6.011980e+15
# 24906        24906       6/29/2020 17:54  5.456710e+15
# 324688      324688      10/23/2020 13:11  4.446370e+15
# 496874      496874       12/19/2020 6:03  3.568740e+15
# 224349      224349        9/8/2020 22:37  4.658490e+15
#
#                              merchant        category     amt       first  \
# 37619                    Lynch-Wisozk            home  135.73      Thomas
# 5400               Stoltenberg-Beatty    shopping_pos    7.33       Paula
# 297501  Denesik, Powlowski and Pouros            home   30.42       Becky
# 367709               Bernier and Sons       kids_pets   27.77  Jacqueline
# 312634     Schumm, Bauch and Ondricka     grocery_pos  121.40        Adam
# ...                               ...             ...     ...         ...
# 94190                      Harber Inc   gas_transport  102.24       Haley
# 24906    Mueller, Gerhold and Mueller  health_fitness   26.97      Pamela
# 324688                  Gibson-Deckow   entertainment   88.35        Ryan
# 496874                       Cole PLC     grocery_pos   92.76      Thomas
# 224349                    Friesen Ltd  health_fitness   88.52        Tara
#
#             last gender                        street  ...    zip      lat  \
# 37619    Jenkins      M             93914 Gregory Via  ...  94619  37.7878
# 5400     Estrada      F               350 Stacy Glens  ...  57374  43.7557
# 297501  Mckinney      F    250 Benjamin Hill Apt. 026  ...  36617  30.7145
# 367709     Curry      F               3047 Jeff Place  ...  79842  30.1886
# 312634      Kirk      M         40847 Stark Junctions  ...  12410  42.0740
# ...          ...    ...                           ...  ...    ...      ...
# 94190     Wagner      F        05561 Farrell Crescent  ...  21405  39.0305
# 24906   Matthews      F     36659 Smith Club Apt. 080  ...  87543  36.1486
# 324688    Joseph      M           8850 Jessica Center  ...  23303  37.9073
# 496874     Cross      M  7566 Thompson Creek Apt. 827  ...  50073  41.8114
# 224349  Richards      F         4879 Cristina Station  ...  15449  39.9636
#
#             long  city_pop                                    job         dob  \
# 37619  -122.1884    381459                                Barista    1/3/1974
# 5400    -97.5936       343  Development worker, international aid    3/5/1972
# 297501  -88.0918    270712               Surveyor, land/geomatics    1/5/1972
# 367709 -103.2214       498                          Lexicographer  11/23/1990
# 312634  -74.4530       397                           Psychiatrist   9/12/1931
# ...          ...       ...                                    ...         ...
# 94190   -76.5515     92106        Accountant, chartered certified   5/28/1943
# 24906  -105.6648       247             Architectural technologist  10/24/1961
# 324688  -75.5089       741                 Geologist, engineering   8/17/1986
# 496874  -93.4855      1195              Trading standards officer   3/13/1974
# 224349  -79.7853       184                      Systems developer   11/4/1945
#
#                                trans_num   unix_time  merch_lat  merch_long
# 37619   e49731efc2fbb517d5da0051e35df13b  1372953301  37.598357 -122.568003
# 5400    18d1bbb52e2b1dd6a238b46c4e0f0ebc  1371933064  43.962352  -98.161012
# 297501  73fc9d9bfbc0c07e029d76b1183dd8f4  1381513955  31.324132  -87.655473
# 367709  5648d0552dc3e2e6f2ade3302b150621  1384106417  29.371713 -103.007225
# 312634  d84963e6710086fb21c9c35487cd5596  1382095672  42.069068  -74.388560
# ...                                  ...         ...        ...         ...
# 94190   5005698f789b6ed4eff539f4902b15aa  1374639351  38.855759  -76.398526
# 24906   1bbe4239b63b8f44706c52c5c451d5fe  1372528461  35.410179 -106.193421
# 324688  79c8d3fc74f49622039aeb398887e8e2  1382533906  38.360321  -75.134437
# 496874  408c3866078e729002b06d7ad8bde9f7  1387433008  42.029854  -93.094708
# 224349  3540c39f0084c1a374991e77f28cdde0  1378679860  40.866382  -79.948349
#
# [361217 rows x 22 columns]

# %%
y_train
# Out:
# 37619     0
# 5400      0
# 297501    0
# 367709    0
# 312634    0
#          ..
# 94190     0
# 24906     0
# 324688    0
# 496874    0
# 224349    0
# Name: is_fraud, Length: 361217, dtype: int64

# %%
clf = linear_model.LogisticRegression(C=1e5)

# %%
clf
# Out:
# LogisticRegression(C=1000000.0)

# %%
clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 clf.fit(x_train, y_train)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1138, in LogisticRegression.fit(self, X, y, sample_weight)
#    1135 else:
#    1136     _dtype = [np.float64, np.float32]
# -> 1138 X, y = self._validate_data(
#    1139     X,
#    1140     y,
#    1141     accept_sparse="csr",
#    1142     dtype=_dtype,
#    1143     order="C",
#    1144     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1145 )
#    1146 check_classification_targets(y)
#    1147 self.classes_ = np.unique(y)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2069, in NDFrame.__array__(self, dtype)
#    2068 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2069     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '7/4/2020 15:55'
